# %%
using CSV
using Plots
using LightGraphs
using JLD2, FileIO
using Statistics
include("EpiSim.jl")
using DelimitedFiles

# %%
readdlm( "Small_WSJ_plotdata.csv", ',')
# Out:
# 150×24 Array{Float64,2}:
#       5.0   5.0         5.0        …   5.0    5.0   5.0   5.0   5.0   5.0
#       5.0   5.0         5.0            5.0    5.0   5.0   5.0   5.0   5.0
#       5.0   5.0         6.0            5.0    5.0   6.0   5.0   5.0   6.0
#       5.0   6.0         7.0            5.0    5.0   6.0   5.0   5.5   6.0
#       5.0   6.0         7.0            5.0    6.0   7.0   5.0   6.0   7.0
#       5.0   6.0         8.0        …   5.0    6.0   7.25  5.0   6.0   7.0
#       6.0   7.0         9.0            6.0    7.0   9.0   5.0   6.0   7.0
#       6.0   8.0        10.0            6.0    7.0   9.0   6.0   7.0   8.0
#       6.0   8.0        11.25           6.75   8.0  10.0   6.0   7.0   8.0
#       7.0   8.5        13.0            7.0    8.5  10.0   6.0   7.0   9.0
#       7.0   9.0        13.0        …   7.0    9.0  11.0   6.0   7.5   9.0
#       8.0   9.0        14.25           7.0    9.0  11.0   7.0   8.0   9.0
# ...

# %%
plotdata=Out[3]
# Out:
# 150×24 Array{Float64,2}:
#       5.0   5.0         5.0        …   5.0    5.0   5.0   5.0   5.0   5.0
#       5.0   5.0         5.0            5.0    5.0   5.0   5.0   5.0   5.0
#       5.0   5.0         6.0            5.0    5.0   6.0   5.0   5.0   6.0
#       5.0   6.0         7.0            5.0    5.0   6.0   5.0   5.5   6.0
#       5.0   6.0         7.0            5.0    6.0   7.0   5.0   6.0   7.0
#       5.0   6.0         8.0        …   5.0    6.0   7.25  5.0   6.0   7.0
#       6.0   7.0         9.0            6.0    7.0   9.0   5.0   6.0   7.0
#       6.0   8.0        10.0            6.0    7.0   9.0   6.0   7.0   8.0
#       6.0   8.0        11.25           6.75   8.0  10.0   6.0   7.0   8.0
#       7.0   8.5        13.0            7.0    8.5  10.0   6.0   7.0   9.0
#       7.0   9.0        13.0        …   7.0    9.0  11.0   6.0   7.5   9.0
#       8.0   9.0        14.25           7.0    9.0  11.0   7.0   8.0   9.0
# ...

# %%
plot([ plotdata[:,2] plotdata[:,8] plotdata[:,14]],yaxis=:log )
plot!([ plotdata[:,5] plotdata[:,11] plotdata[:,17]],yaxis=:log ,linestyle=:dash)
