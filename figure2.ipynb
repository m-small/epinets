# %%
using JLD2

# %%
@load "parameters_th100" C swaps p2s r2s mti mmi r50
# Out:
# 7-element Array{Symbol,1}:
#  :C
#  :swaps
#  :p2s
#  :r2s
#  :mti
#  :mmi
#  :r50

# %%
C
# Out:
# 8-element Array{Float64,1}:
#  1.0
#  0.99
#  0.95
#  0.9
#  0.8
#  0.7
#  0.6
#  0.5

# %%
swaps
# Out:
# 8-element Array{Float64,1}:
#  0.0
#  0.002509430066318874
#  0.012741455098566168
#  0.025996253574703254
#  0.05425839099682417
#  0.08530878077130555
#  0.11988826320660662
#  0.1591035847462855

# %%
using Plots

# %%
Plots.plot(r2s,p2s,mti[1,:,:],st=:surface)

# %%
i=2
p1=Plots.plot(r2s,p2s,log.(mti[i,:,:])./log(10),st=:surface,xlabel="r",ylabel="p",zlabel="log(total I)",colorbar=false,title="(a) $(Int(C[i]*100))%" )
i=4
p2=Plots.plot(r2s,p2s,log.(mti[i,:,:])./log(10),st=:surface,xlabel="r",ylabel="p",zlabel="log(total I)",colorbar=false,title="(b) $(Int(C[i]*100))%" )
i=5
p3=Plots.plot(r2s,p2s,log.(mti[i,:,:])./log(10),st=:surface,xlabel="r",ylabel="p",zlabel="log(total I)",colorbar=false,title="(c) $(Int(C[i]*100))%" )
i=6
p4=Plots.plot(r2s,p2s,log.(mti[i,:,:])./log(10),st=:surface,xlabel="r",ylabel="p",zlabel="log(total I)",colorbar=false,title="(d) $(Int(C[i]*100))%" )

# %%
Plots.plot(p1,p2,p3,p4,layout=(2,2))
